# %%
import pandas as pd
import statsmodels.api as sm
from plotnine import *
from clean_data import *

# %%
df = pd.read_csv("data/loan_level_500k.csv", low_memory=False)
df.head()
# Out:
#    CREDIT_SCORE  FIRST_PAYMENT_DATE FIRST_TIME_HOMEBUYER_FLAG  MATURITY_DATE  \
# 0         669.0              200206                         N         202901
# 1         732.0              199904                         N         202903
# 2         679.0              200208                         N         202902
# 3         721.0              200209                         N         202902
# 4         618.0              200210                         N         202902
#
#    METROPOLITAN_STATISTICAL_AREA  MORTGAGE_INSURANCE_PERCENTAGE  \
# 0                            NaN                            0.0
# 1                        17140.0                            0.0
# 2                        15940.0                           30.0
# 3                        38060.0                            0.0
# 4                        10420.0                           25.0
#
#    NUMBER_OF_UNITS OCCUPANCY_STATUS  ORIGINAL_COMBINED_LOAN_TO_VALUE  \
# ...

# %%
df = tidy_data(df)
df.head()
# Out:
#    CREDIT_SCORE FIRST_TIME_HOMEBUYER_FLAG  METROPOLITAN_STATISTICAL_AREA  \
# 0         669.0                         N                            NaN
# 1         732.0                         N                        17140.0
# 2         679.0                         N                        15940.0
# 3         721.0                         N                        38060.0
# 4         618.0                         N                        10420.0
#
#    MORTGAGE_INSURANCE_PERCENTAGE  NUMBER_OF_UNITS OCCUPANCY_STATUS  \
# 0                            0.0              1.0                O
# 1                            0.0              1.0                O
# 2                           30.0              1.0                O
# 3                            0.0              1.0                O
# 4                           25.0              1.0                O
#
#    ORIGINAL_COMBINED_LOAN_TO_VALUE  ORIGINAL_DEBT_TO_INCOME_RATIO  \
# ...

# %%
train, test, _ = get_train_test_split_for_ml(df, 2000)
train.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/computation/scope.py in resolve(self, key, is_local)
#     186             if self.has_resolvers:
# --> 187                 return self.resolvers[key]
#     188
#
# ~/anaconda3/lib/python3.7/collections/__init__.py in __getitem__(self, key)
#     915                 pass
# --> 916         return self.__missing__(key)            # support subclasses that define __missing__
#     917
#
# ~/anaconda3/lib/python3.7/collections/__init__.py in __missing__(self, key)
#     907     def __missing__(self, key):
# --> 908         raise KeyError(key)
#     909
#
# KeyError: 'split_year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# null -> not linearly correlated (credit score and original ubp)

# %%
#reg = sm.ols('ORIGINAL_UPB ~ CREDIT_SCORE', data=df).fit()

df.exog = sm.add_constant(df.exog)

#reg = sm.Logit('DELINQUENT ~ CREDIT_SCORE + FIRST_PAYMENT_DATE + FIRST_TIME_HOMEBUYER_FLAG+MATURITY_DATE+METROPOLITAN_STATISTICAL_AREA+MORTGAGE_INSURANCE_PERCENTAGE+NUMBER_OF_UNITS+OCCUPANCY_STATUS+ORIGINAL_COMBINED_LOAN_TO_VALUE+ORIGINAL_DEBT_TO_INCOME_RATIO+...+PROPERTY_TYPE+POSTAL_CODE+LOAN_SEQUENCE_NUMBER+LOAN_PURPOSE+ORIGINAL_LOAN_TERM+NUMBER_OF_BORROWERS+SELLER_NAME+SERVICER_NAME+PREPAID', data=df).fit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-b4b3404ab0eb> in <module>
#       1 #reg = sm.ols('ORIGINAL_UPB ~ CREDIT_SCORE', data=df).fit()
#       2
# ----> 3 df.exog = sm.add_constant(df.exog)
#       4
#       5 #reg = sm.Logit('DELINQUENT ~ CREDIT_SCORE + FIRST_PAYMENT_DATE + FIRST_TIME_HOMEBUYER_FLAG+MATURITY_DATE+METROPOLITAN_STATISTICAL_AREA+MORTGAGE_INSURANCE_PERCENTAGE+NUMBER_OF_UNITS+OCCUPANCY_STATUS+ORIGINAL_COMBINED_LOAN_TO_VALUE+ORIGINAL_DEBT_TO_INCOME_RATIO+...+PROPERTY_TYPE+POSTAL_CODE+LOAN_SEQUENCE_NUMBER+LOAN_PURPOSE+ORIGINAL_LOAN_TERM+NUMBER_OF_BORROWERS+SELLER_NAME+SERVICER_NAME+PREPAID', data=df).fit()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# ...

# %%
reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:           ORIGINAL_UPB   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     46.26
# Date:                Mon, 11 May 2020   Prob (F-statistic):           1.04e-11
# Time:                        16:08:12   Log-Likelihood:            -6.1862e+06
# No. Observations:              497426   AIC:                         1.237e+07
# Df Residuals:                  497424   BIC:                         1.237e+07
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...
